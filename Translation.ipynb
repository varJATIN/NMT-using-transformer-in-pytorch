# %%
import torch
import  numpy
import spacy
import torchtext
from torchtext.data import Field,BucketIterator,TabularDataset

# %%
#loading datafiles in english and french seperately
europarl_en = open('/content/europarl-v7.fr-en.en', encoding='utf-8').read().split('\n')
europarl_fr = open('/content/europarl-v7.fr-en.fr', encoding='utf-8').read().split('\n')

# %%
en=spacy.load('en')#loading english language framework for processing

# %%
# !python -m spacy download fr
fr=spacy.load('fr')#loading french language framework for processing
# Out:
# Collecting fr_core_news_sm==2.1.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/fr_core_news_sm-2.1.0/fr_core_news_sm-2.1.0.tar.gz (13.1MB)
#      |████████████████████████████████| 13.1MB 611kB/s
# Building wheels for collected packages: fr-core-news-sm
#   Building wheel for fr-core-news-sm (setup.py) ... done
#   Created wheel for fr-core-news-sm: filename=fr_core_news_sm-2.1.0-cp36-none-any.whl size=13156209 sha256=f0eacb6e1d8075b0840a766aa68a9a3d7a87553d08cb2f779e3b9ca2cc4e1723
#   Stored in directory: /tmp/pip-ephem-wheel-cache-x9xw1c27/wheels/ab/82/2a/61dd0ff02e22f10eef65a5aa35453a0eb745c84b4c874b612f
# Successfully built fr-core-news-sm
# Installing collected packages: fr-core-news-sm
# Successfully installed fr-core-news-sm-2.1.0
# ✔ Download and installation successful
# You can now load the model via spacy.load('fr_core_news_sm')
# ✔ Linking successful
# /usr/local/lib/python3.6/dist-packages/fr_core_news_sm -->
# /usr/local/lib/python3.6/dist-packages/spacy/data/fr
# You can now load the model via spacy.load('fr')

# %%
import pandas as pd
#creat ing a dictionary with 'english' and 'french' as key
raw_data={'English':[line for line in europarl_en],'French':[line for line in europarl_fr]}

# %%
df=pd.DataFrame.from_dict(raw_data,orient='index')

# %%
df=df.transpose()

# %%
#4th row
df.iloc[4,:]
# Out:
# English    In the meantime, I should like to observe a mi...
# French     En attendant, je souhaiterais, comme un certai...
# Name: 4, dtype: object

# %%
#adding columns with the length of the sentences
df['eng_len'] = df['English'].str.count(' ')
df['fr_len'] = df['French'].str.count(' ')

# %%
df #we need to del the rows with the nan values
# Out:
#                                                   English  ... fr_len
# 0                               Resumption of the session  ...    3.0
# 1       I declare resumed the session of the European ...  ...   32.0
# 2       Although, as you will have seen, the dreaded '...  ...   36.0
# 3       You have requested a debate on this subject in...  ...   18.0
# 4       In the meantime, I should like to observe a mi...  ...   37.0
# ...                                                   ...  ...    ...
# 646473  So please go ahead and ask the President-in-Of...  ...    NaN
# 646474     That is very gracious of you, Madam Preside...  ...    NaN
# 646475                                 That is very fair.  ...    NaN
# 646476  We shall continue to discuss what is to be don...  ...    NaN
# 646477                       The Council is aware of the   ...    NaN
#
# [646478 rows x 4 columns]

# %%
df=df.dropna(axis=0,subset=['fr_len'])
df.shape
# Out:
# (565963, 4)

# %%
#remove long sentences and others with large difference in the translations 
df = df.query('fr_len < 80 & eng_len < 80')
df = df.query('fr_len < eng_len * 1.5 & fr_len * 1.5 > eng_len')

# %%
df.shape
# Out:
# (249594, 4)

# %%
from sklearn.model_selection import train_test_split
train,val=train_test_split(df,test_size=0.1)

# %%
train.shape
# Out:
# (224634, 4)

# %%
#saving the train and val to csv files
train.to_csv("train.csv", index=False)
val.to_csv("val.csv", index=False)

# %%
def tokenize_en(sentence):
    return [tok.text for tok in en.tokenizer(sentence)]
def tokenize_fr(sentence):
    return [tok.text for tok in fr.tokenizer(sentence)]
#creating two field object to  tokemize and split the data and passing the custom tokenizer function
EN_TEXT = Field(tokenize=tokenize_en)
FR_TEXT = Field(tokenize=tokenize_fr, init_token = "<sos>", eos_token = "<eos>")

# %%
# associate the text in the 'English' column with the EN_TEXT field, # and 'French' with FR_TEXT
data_fields = [('English', EN_TEXT), ('French', FR_TEXT)]

train,val = TabularDataset.splits(path='/content/', train='train.csv', validation='val.csv', format='csv', fields=data_fields)

# %%
sz=3
mask=torch.triu(torch.ones(sz, sz))
mask=(torch.triu(torch.ones(sz, sz)) == 1)

# %%
mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
# Out:
# tensor([[0., 0., 0.],
#         [-inf, 0., 0.],
#         [-inf, -inf, 0.]])

# %%
FR_TEXT.build_vocab(train, val)
EN_TEXT.build_vocab(train, val)

# %%
#check the index of any word
FR_TEXT.vocab.stoi ['the']  #<unk>:0,<pad>:1,<sos>:2,<eos>:3
# Out:
# 6548

# %%
#Defines an iterator that batches examples of similar lengths together hence reducing the amount of the padding
train_iter = BucketIterator(train, batch_size=20, sort_key=lambda x: len(x.French), shuffle=True)

# %%
#batch=(next(iter(train_iter)))

# %%
for i,n in enumerate(train_iter):
  print(i,"\n",n)
# Out:
# 0
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 47x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 1
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 63x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 2
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 73x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 3
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 73x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 4
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 83x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 5
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 6
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 7
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 77x20]
# 	[.French]:[torch.LongTensor of size 87x20]
# 8
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 83x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 9
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 79x20]
# 10
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 74x20]
# 11
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 44x20]
# 	[.French]:[torch.LongTensor of size 53x20]
# 12
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 70x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 13
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 72x20]
# 14
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 81x20]
# 15
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 73x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 16
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 75x20]
# 17
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 18
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 19
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 63x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 20
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 49x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 21
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 77x20]
# 22
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 67x20]
# 	[.French]:[torch.LongTensor of size 52x20]
# 23
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 24
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 86x20]
# 	[.French]:[torch.LongTensor of size 87x20]
# 25
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 39x20]
# 	[.French]:[torch.LongTensor of size 39x20]
# 26
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 27
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 69x20]
# 	[.French]:[torch.LongTensor of size 71x20]
# 28
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 29
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 30
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 31
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 69x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 32
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 79x20]
# 	[.French]:[torch.LongTensor of size 74x20]
# 33
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 34
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 35
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 68x20]
# 	[.French]:[torch.LongTensor of size 64x20]
# 36
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 70x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 37
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 38
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 39
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 40
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 75x20]
# 	[.French]:[torch.LongTensor of size 94x20]
# 41
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 42
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 43
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 44
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 44x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 45
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 70x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 46
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 55x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 47
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 79x20]
# 48
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 75x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 49
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 47x20]
# 	[.French]:[torch.LongTensor of size 36x20]
# 50
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 81x20]
# 	[.French]:[torch.LongTensor of size 101x20]
# 51
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 52
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 66x20]
# 53
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 46x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 54
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 55
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 82x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 56
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 57
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 58
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 46x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 59
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 64x20]
# 60
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 62x20]
# 	[.French]:[torch.LongTensor of size 66x20]
# 61
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 62
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 63
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 67x20]
# 	[.French]:[torch.LongTensor of size 71x20]
# 64
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 91x20]
# 65
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 66
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 63x20]
# 	[.French]:[torch.LongTensor of size 75x20]
# 67
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 46x20]
# 	[.French]:[torch.LongTensor of size 51x20]
# 68
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 69
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 70
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 49x20]
# 	[.French]:[torch.LongTensor of size 53x20]
# 71
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 72x20]
# 72
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 73
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 43x20]
# 	[.French]:[torch.LongTensor of size 47x20]
# 74
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 75
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 55x20]
# 76
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 77
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 78
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 79x20]
# 	[.French]:[torch.LongTensor of size 97x20]
# 79
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 49x20]
# 	[.French]:[torch.LongTensor of size 64x20]
# 80
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 80x20]
# 	[.French]:[torch.LongTensor of size 94x20]
# 81
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 66x20]
# 82
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 44x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 83
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 44x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 84
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 47x20]
# 	[.French]:[torch.LongTensor of size 55x20]
# 85
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 50x20]
# 86
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 73x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 87
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 88
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 53x20]
# 89
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 68x20]
# 90
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 81x20]
# 	[.French]:[torch.LongTensor of size 52x20]
# 91
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 92
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 93
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 94
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 43x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 95
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 96
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 43x20]
# 	[.French]:[torch.LongTensor of size 43x20]
# 97
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 68x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 98
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 77x20]
# 99
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 40x20]
# 	[.French]:[torch.LongTensor of size 49x20]
# 100
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 101
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 87x20]
# 102
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 69x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 103
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 104
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 80x20]
# 105
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 85x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 106
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 77x20]
# 	[.French]:[torch.LongTensor of size 88x20]
# 107
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 76x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 108
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 52x20]
# 109
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 76x20]
# 	[.French]:[torch.LongTensor of size 71x20]
# 110
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 111
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 96x20]
# 112
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 113
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 114
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 80x20]
# 	[.French]:[torch.LongTensor of size 74x20]
# 115
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 45x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 116
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 49x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 117
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 46x20]
# 	[.French]:[torch.LongTensor of size 73x20]
# 118
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 64x20]
# 119
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 45x20]
# 120
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 68x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 121
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 84x20]
# 	[.French]:[torch.LongTensor of size 88x20]
# 122
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 123
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 77x20]
# 124
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 125
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 39x20]
# 	[.French]:[torch.LongTensor of size 45x20]
# 126
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 127
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 46x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 128
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 56x20]
# 	[.French]:[torch.LongTensor of size 56x20]
# 129
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 56x20]
# 130
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 131
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 41x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 132
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 75x20]
# 	[.French]:[torch.LongTensor of size 81x20]
# 133
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 87x20]
# 	[.French]:[torch.LongTensor of size 84x20]
# 134
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 68x20]
# 	[.French]:[torch.LongTensor of size 74x20]
# 135
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 56x20]
# 	[.French]:[torch.LongTensor of size 49x20]
# 136
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 85x20]
# 137
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 138
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 139
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 70x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 140
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 49x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 141
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 78x20]
# 	[.French]:[torch.LongTensor of size 81x20]
# 142
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 40x20]
# 	[.French]:[torch.LongTensor of size 55x20]
# 143
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 55x20]
# 144
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 56x20]
# 145
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 146
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 147
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 148
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 149
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 150
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 151
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 152
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 55x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 153
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 67x20]
# 	[.French]:[torch.LongTensor of size 84x20]
# 154
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 51x20]
# 155
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 40x20]
# 	[.French]:[torch.LongTensor of size 51x20]
# 156
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 80x20]
# 	[.French]:[torch.LongTensor of size 86x20]
# 157
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 76x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 158
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 159
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 86x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 160
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 62x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 161
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 52x20]
# 162
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 62x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 163
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 65x20]
# 164
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 165
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 45x20]
# 	[.French]:[torch.LongTensor of size 49x20]
# 166
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 95x20]
# 167
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 168
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 169
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 38x20]
# 	[.French]:[torch.LongTensor of size 44x20]
# 170
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 67x20]
# 171
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 80x20]
# 	[.French]:[torch.LongTensor of size 77x20]
#
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 94x20]
# 11166
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 56x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 11167
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 11168
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 39x20]
# 	[.French]:[torch.LongTensor of size 40x20]
# 11169
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 11170
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 11171
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 51x20]
# 11172
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 83x20]
# 	[.French]:[torch.LongTensor of size 64x20]
# 11173
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 72x20]
# 11174
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 81x20]
# 	[.French]:[torch.LongTensor of size 98x20]
# 11175
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 76x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 11176
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 70x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 11177
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 43x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 11178
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 54x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 11179
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 71x20]
# 11180
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 94x20]
# 11181
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 43x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 11182
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 63x20]
# 	[.French]:[torch.LongTensor of size 68x20]
# 11183
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 67x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 11184
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 50x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 11185
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 53x20]
# 	[.French]:[torch.LongTensor of size 75x20]
# 11186
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 53x20]
# 11187
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 45x20]
# 	[.French]:[torch.LongTensor of size 45x20]
# 11188
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 55x20]
# 	[.French]:[torch.LongTensor of size 66x20]
# 11189
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 11190
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 56x20]
# 	[.French]:[torch.LongTensor of size 61x20]
# 11191
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 47x20]
# 11192
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 39x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 11193
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 42x20]
# 	[.French]:[torch.LongTensor of size 54x20]
# 11194
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 47x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 11195
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 79x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 11196
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 74x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 11197
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 11198
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 11199
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 47x20]
# 	[.French]:[torch.LongTensor of size 56x20]
# 11200
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 11201
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 62x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 11202
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 11203
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 11204
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 61x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 11205
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 76x20]
# 	[.French]:[torch.LongTensor of size 82x20]
# 11206
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 45x20]
# 	[.French]:[torch.LongTensor of size 49x20]
# 11207
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 63x20]
# 	[.French]:[torch.LongTensor of size 77x20]
# 11208
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 44x20]
# 	[.French]:[torch.LongTensor of size 56x20]
# 11209
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 39x20]
# 	[.French]:[torch.LongTensor of size 53x20]
# 11210
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 63x20]
# 11211
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 83x20]
# 	[.French]:[torch.LongTensor of size 90x20]
# 11212
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 59x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 11213
#
# [torchtext.data.batch.Batch of size 15]
# 	[.English]:[torch.LongTensor of size 48x15]
# 	[.French]:[torch.LongTensor of size 62x15]
# 11214
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 11215
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 48x20]
# 	[.French]:[torch.LongTensor of size 48x20]
# 11216
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 78x20]
# 11217
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 57x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 11218
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 51x20]
# 	[.French]:[torch.LongTensor of size 52x20]
# 11219
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 71x20]
# 	[.French]:[torch.LongTensor of size 58x20]
# 11220
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 55x20]
# 	[.French]:[torch.LongTensor of size 76x20]
# 11221
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 52x20]
# 	[.French]:[torch.LongTensor of size 62x20]
# 11222
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 67x20]
# 	[.French]:[torch.LongTensor of size 70x20]
# 11223
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 89x20]
# 11224
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 66x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 11225
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 65x20]
# 	[.French]:[torch.LongTensor of size 57x20]
# 11226
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 64x20]
# 	[.French]:[torch.LongTensor of size 72x20]
# 11227
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 58x20]
# 	[.French]:[torch.LongTensor of size 69x20]
# 11228
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 72x20]
# 	[.French]:[torch.LongTensor of size 91x20]
# 11229
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 60x20]
# 	[.French]:[torch.LongTensor of size 59x20]
# 11230
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 55x20]
# 	[.French]:[torch.LongTensor of size 60x20]
# 11231
#
# [torchtext.data.batch.Batch of size 20]
# 	[.English]:[torch.LongTensor of size 75x20]
# 	[.French]:[torch.LongTensor of size 82x20]

# %%
#tr_en=(batch.English)# sentence_length*batch_size
#tr_target=(batch.French)#20 is the batch
#tr_en.shape

# %%
import torch
import torch.nn as nn
import math
import torch.nn.functional as F

# %%
class TransformerModel(nn.Module):
  def __init__(self, vocab_size_en,vocab_size_fr, dim_input, nos_head, fd_frwd, nlayers, dropout=0.5):
    super(TransformerModel, self).__init__()
    from torch.nn import TransformerEncoderLayer,TransformerEncoder,TransformerDecoder,TransformerDecoderLayer, Embedding
    self.src_mask=None
    self.embed_en =Embedding(vocab_size_en,dim_input)
    self.pos_encoder=PositionalEncoding(dim_input)
    encoder_layers=TransformerEncoderLayer(dim_input,nos_head,fd_frwd,dropout)
    self.encoder=TransformerEncoder(encoder_layers,nlayers)
    self.dim_input=dim_input
    self.nlayers=nlayers
    self.embed_fr=Embedding(vocab_size_fr,dim_input)
    self.pos_decoder=PositionalEncoding(dim_input)
    dec_layers=TransformerDecoderLayer(dim_input,nos_head,fd_frwd,dropout)
    self.decoder=TransformerDecoder(dec_layers,nlayers)
    self.decoder_out_layer=nn.Linear(dim_input,vocab_size_fr)
    self.output_final=nn.Softmax()
    self.init_weights()
  def _generate_square_subsequent_mask(self, sz):
    mask = (torch.triu(torch.ones(sz, sz)) == 1).transpose(0, 1)
    mask = mask.float().masked_fill(mask == 0, float('-inf')).masked_fill(mask == 1, float(0.0))
    return mask
  
  def init_weights(self):
    initrange = 0.1
    self.embed_en.weight.data.uniform_(-initrange, initrange)
    self.embed_fr.weight.data.uniform_(-initrange, initrange)
    self.decoder_out_layer.bias.data.zero_()
    self.decoder_out_layer.weight.data.uniform_(-initrange, initrange)
  
  def forward(self,inp,target):
    inp=self.embed_en(inp)
    inp=self.pos_encoder(inp)
    encoder_output = self.encoder(inp)
    #print(encoder_output.shape)
    #print(self.src_mask == None or self.src_mask.size(0) != len(target))
    if (self.src_mask == None or self.src_mask.size(0) != len(target)): 
      device = target.device
      #print(len(target))
      mask = self._generate_square_subsequent_mask(len(target)).to(device)
      src_mask = mask
      #print(src_mask)
    target = self.embed_fr(target) 
    target = self.pos_decoder(target)
    #print(target.shape)
    output = self.decoder(target,encoder_output,src_mask,memory_mask=None,tgt_key_padding_mask=None, memory_key_padding_mask=None)
    output = self.decoder_out_layer(output)
    out=self.output_final(output)
    return out

# %%
vocab_size_fr=len(FR_TEXT.vocab.stoi)
vocab_size_en=len(EN_TEXT.vocab.stoi)
dim_input=256
nos_head=4
nlayers=4
fd_frwd=512

# %%
class PositionalEncoding(nn.Module):

    def __init__(self, d_model, max_seq_len=120):
        super(PositionalEncoding, self).__init__()
        pe = torch.zeros((max_seq_len, d_model))
        position = torch.arange(0, max_seq_len, dtype=torch.float).unsqueeze(1)
        div_term = torch.exp(torch.arange(0, d_model, 2).float() * (-math.log(10000.0) / d_model))
        pe[:, 0::2] = torch.sin(position * div_term)
        pe[:, 1::2] = torch.cos(position * div_term)
        pe = pe.unsqueeze(0).transpose(0, 1)
        self.register_buffer('pe', pe)

    def forward(self, x):
        x = x + self.pe[:x.size(0), :]
        return (x)

# %%
model=TransformerModel(vocab_size_en,vocab_size_fr,dim_input,nos_head,fd_frwd,nlayers)

# %%
import time
criterion = nn.CrossEntropyLoss()
lr = 5.0 # learning rate
optimizer = torch.optim.SGD(model.parameters(), lr=lr)
scheduler = torch.optim.lr_scheduler.StepLR(optimizer, 1.0, gamma=0.95) 
start_time=time.time()
tot_loss=0
for i,batch in enumerate(train_iter):
  #print("batch",i)
 
  tr_en=batch.English
  tr_target=batch.French
  optimizer.zero_grad()                     
  model.train() 
  output = model(tr_en,tr_target)
  loss = criterion(output.view(-1, vocab_size_fr), tr_target.view(-1))
  loss.backward()
  optimizer.step()
  log_interval = 200
  tot_loss+=loss
  #print the loss and time per 200 batches
  if i%200 ==0 :
    elapsed = time.time() - start_time
    print("loss:",tot_loss,"\t","time:",elapsed)
    tot_loss=0
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:48: UserWarning: Implicit dimension choice for softmax has been deprecated. Change the call to include dim=X as an argument.
# loss: tensor(11.0471, grad_fn=<AddBackward0>) 	 time: 10.830580711364746
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-39-3c9d9a364f75> in <module>()
#      15   output = model(tr_en,tr_target)
#      16   loss = criterion(output.view(-1, vocab_size_fr), tr_target.view(-1))
# ---> 17   loss.backward()
#      18   optimizer.step()
#      19   log_interval = 200
#
# /usr/local/lib/python3.6/dist-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#     164                 products. Defaults to ``False``.
#     165         """
# --> 166         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     167
#     168     def register_hook(self, hook):
#
# /usr/local/lib/python3.6/dist-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      97     Variable._execution_engine.run_backward(
#      98         tensors, grad_tensors, retain_graph, create_graph,
# ---> 99         allow_unreachable=True)  # allow_unreachable flag
#     100
#     101
#
# KeyboardInterrupt:

# %%
vocab_size_fr

# %%
output.view(-1, vocab_size_fr).shape

# %%
tr_target.shape

# %%
tr_target.view(-1).shape
